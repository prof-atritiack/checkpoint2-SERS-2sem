# %% [markdown]
# <a href="https://colab.research.google.com/github/prof-atritiack/checkpoint2-SERS-2sem/blob/main/AULA_06_SERS_ML_ENERGIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##EXERCÍCIO
#
# Treinar um modelo preditivo de classificação usando Regressão Logística (diretamente do sklearn) para prever se a rede elétrica está "estável" ou "instável" com base no dataset "Electrical Grid Stability Simulated Data"
#
# Fonte dos dados: https://archive.ics.uci.edu/dataset/471/electrical+grid+stability+simulated+data

# %% [markdown]
# PREPARAÇÃO DO AMBIENTE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Algoritmo de Regressão Logística
from sklearn.linear_model import LogisticRegression
# Separação de dados de treino e teste (X_train, X_test, y_train, y_test)
from sklearn.model_selection import train_test_split
# Métricas de avaliação do modelo
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# ##CARREGAMENTO DOS DADOS E CRIAÇÃO DO DATAFRAME

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/prof-atritiack/checkpoint2-SERS-2sem/refs/heads/main/Data_for_UCI_named.csv')

# %%
dados.head()
# Out:
#        tau1      tau2      tau3  ...        g4      stab     stabf
# 0  2.959060  3.079885  8.381025  ...  0.958034  0.055347  unstable
# 1  9.304097  4.902524  3.047541  ...  0.781760 -0.005957    stable
# 2  8.971707  8.848428  3.046479  ...  0.109853  0.003471  unstable
# 3  0.716415  7.669600  4.486641  ...  0.362718  0.028871  unstable
# 4  3.134112  7.608772  4.943759  ...  0.820923  0.049860  unstable
#
# [5 rows x 14 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
# Quais classes temos na coluna 'stabf'
dados['stabf'].unique()
# Out:
# array(['unstable', 'stable'], dtype=object)

# %%
# Quantos registros de cada classe temos na coluna 'stabf'
dados['stabf'].value_counts()
# Out:
# stabf
# unstable    6380
# stable      3620
# Name: count, dtype: int64

# %%
# Para colunas categóricas:
dados.describe(include='object')
# Out:
#            stabf
# count      10000
# unique         2
# top     unstable
# freq        6380

# %%
# Estatísticas descritivas
# Para colunas numéricas:
dados.describe()
# Out:
#                tau1          tau2  ...            g4          stab
# count  10000.000000  10000.000000  ...  10000.000000  10000.000000
# mean       5.250000      5.250001  ...      0.525000      0.015731
# std        2.742548      2.742549  ...      0.274255      0.036919
# min        0.500793      0.500141  ...      0.050028     -0.080760
# 25%        2.874892      2.875140  ...      0.287494     -0.015557
# 50%        5.250004      5.249981  ...      0.525002      0.017142
# 75%        7.624690      7.624893  ...      0.762433      0.044878
# max        9.999469      9.999837  ...      0.999930      0.109403
#
# [8 rows x 13 columns]

# %%
dados.columns
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4', 'stab', 'stabf'],
#       dtype='object')

# %%
# Dados de entrada --------> Features ----> variáveis independentes ----> DataFrame X (maiúsculo)
X = dados.drop(['stab', 'stabf'], axis=1)
X.head()
# Out:
#        tau1      tau2      tau3  ...        g2        g3        g4
# 0  2.959060  3.079885  8.381025  ...  0.859578  0.887445  0.958034
# 1  9.304097  4.902524  3.047541  ...  0.862414  0.562139  0.781760
# 2  8.971707  8.848428  3.046479  ...  0.766689  0.839444  0.109853
# 3  0.716415  7.669600  4.486641  ...  0.976744  0.929381  0.362718
# 4  3.134112  7.608772  4.943759  ...  0.455450  0.656947  0.820923
#
# [5 rows x 12 columns]

# %%
# Dados de saída --------> target -------> variável dependente ------> array y (minúsculo)
y = dados['stabf']
y.head()
# Out:
# 0    unstable
# 1      stable
# 2    unstable
# 3    unstable
# 4    unstable
# Name: stabf, dtype: object

# %%
# Separação de dados de treino e teste ----> train_test_split
# X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

# %%
X.shape
# Out:
# (10000, 12)

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
X_test.shape
# Out:
# (2000, 12)

# %% [markdown]
# ##TREINAMENTO DO MODELO PREDITIVO DE CLASSIFICAÇÃO

# %%
# Instanciando o modelo com base no algoritmo Logistic Regression
modelo_LR = LogisticRegression()

# %%
# Treinamento do modelo
modelo_LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Gerando as previsões
y_predict = modelo_LR.predict(X_test)
y_predict
# Out:
# array(['unstable', 'unstable', 'unstable', ..., 'stable', 'unstable',
#        'unstable'], dtype=object)

# %%
# Avaliar o modelo (somente a acurácia)
acuracia = 100 * accuracy_score(y_test, y_predict)
print(f'A acurácia do modelo baseado em Regressão Logística é: {acuracia:.2f} %')
# Out:
# A acurácia do modelo baseado em Regressão Logística é: 82.45 %

# %%
# Matriz de confusão usando o matplotlib e o seaborn

# %%
X_test.shape
# Out:
# (2000, 12)

# %%
cm = confusion_matrix(y_test, y_predict)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Stable', 'Unstable'], yticklabels=['Stable', 'Unstable'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
